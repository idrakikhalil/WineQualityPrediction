# %%
#dataanalysisandwrangling 
import pandas as pd
import numpy as np
import seaborn as sns
#visualization importseabornassns
import matplotlib.pyplot as plt
# %matplotlib inline
#scalingandtraintestsplit
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, LabelEncoder

#creatingamodel
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import SGD

file_path = 'R_W_Wine_quality.csv'
data1 = pd.read_csv(file_path)
data1

df=data1[data1['type']=='White']
df

data=df
data

features = ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol']
y1_labels = ['quality']
y2_labels = ['type']

X = data[features]
y1 = data[y1_labels]
y2 = data[y2_labels]

X_train, X_test, y1_train, y1_test = train_test_split(X, y1, test_size=0.2, random_state=42)

X_train_scaled = MinMaxScaler().fit_transform(X_train[features])
X_test_scaled = MinMaxScaler().fit_transform(X_test[features])


label_encoder = LabelEncoder()


y1_train_encoded = label_encoder.fit_transform(y1_train)
y1_test_encoded = label_encoder.fit_transform(y1_test)

model = Sequential([
    Dense(64, activation='relu', input_shape=(11,)),
    Dense(32, activation='relu'),
    Dense(7, activation='softmax')  
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',  # Use sparse categorical crossentropy
              metrics=['accuracy'])


history = model.fit(X_train_scaled, y1_train_encoded, validation_split=0.2, epochs=100, batch_size=100, verbose=1)

training_loss=history.history['loss']
epochs = range(1, len(training_loss) + 1)

#plotting the training loss
plt.figure(figsize=(10,6))
plt.plot(epochs, training_loss, 'bo-', label='Training Loss')
plt.title('Training Loss Per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()

predictions = model.predict(X_test_scaled)

predicted_classes = predictions.argmax(axis=1)

predicted_labels = label_encoder.inverse_transform(predicted_classes)



for predicted_label, actual_label1 in zip(predicted_labels, y1_test_encoded):
    actual_label_name1 = label_encoder.inverse_transform([actual_label1])
    
    print(f"Predicted class: {predicted_label}, Actual class: {actual_label_name1}")

correct_predictions = (predicted_labels == label_encoder.inverse_transform(y1_test_encoded)).sum()
accuracy = correct_predictions / len(y1_test)
print(f"Accuracy:{accuracy:.4f}")
# Out:
# C:\Users\idrak\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\idrak\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\idrak\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:86: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.2232 - loss: 1.8585 - val_accuracy: 0.3304 - val_loss: 1.5698
# Epoch 2/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4081 - loss: 1.4789 - val_accuracy: 0.4579 - val_loss: 1.2869
# Epoch 3/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4430 - loss: 1.2998 - val_accuracy: 0.4579 - val_loss: 1.2447
# Epoch 4/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4605 - loss: 1.2538 - val_accuracy: 0.4898 - val_loss: 1.2161
# Epoch 5/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4882 - loss: 1.2373 - val_accuracy: 0.5115 - val_loss: 1.1911
# Epoch 6/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5154 - loss: 1.1805 - val_accuracy: 0.5153 - val_loss: 1.1729
# Epoch 7/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5183 - loss: 1.1636 - val_accuracy: 0.5281 - val_loss: 1.1587
# Epoch 8/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5118 - loss: 1.1675 - val_accuracy: 0.5293 - val_loss: 1.1459
# Epoch 9/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5193 - loss: 1.1418 - val_accuracy: 0.5332 - val_loss: 1.1366
# Epoch 10/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5168 - loss: 1.1460 - val_accuracy: 0.5281 - val_loss: 1.1305
# Epoch 11/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5375 - loss: 1.1246 - val_accuracy: 0.5344 - val_loss: 1.1268
# Epoch 12/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5165 - loss: 1.1332 - val_accuracy: 0.5319 - val_loss: 1.1255
# Epoch 13/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5349 - loss: 1.1128 - val_accuracy: 0.5306 - val_loss: 1.1156
# Epoch 14/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5407 - loss: 1.1146 - val_accuracy: 0.5472 - val_loss: 1.1134
# Epoch 15/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5465 - loss: 1.0890 - val_accuracy: 0.5408 - val_loss: 1.1180
# Epoch 16/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5374 - loss: 1.0969 - val_accuracy: 0.5370 - val_loss: 1.1107
# Epoch 17/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5387 - loss: 1.0905 - val_accuracy: 0.5395 - val_loss: 1.1078
# Epoch 18/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5335 - loss: 1.1092 - val_accuracy: 0.5395 - val_loss: 1.1113
# Epoch 19/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5291 - loss: 1.0937 - val_accuracy: 0.5395 - val_loss: 1.1084
# Epoch 20/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5412 - loss: 1.0997 - val_accuracy: 0.5357 - val_loss: 1.1073
# Epoch 21/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5468 - loss: 1.0950 - val_accuracy: 0.5446 - val_loss: 1.1072
# Epoch 22/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5259 - loss: 1.0916 - val_accuracy: 0.5383 - val_loss: 1.1003
# Epoch 23/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5469 - loss: 1.0856 - val_accuracy: 0.5408 - val_loss: 1.0997
# Epoch 24/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5424 - loss: 1.0844 - val_accuracy: 0.5421 - val_loss: 1.1040
# Epoch 25/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5485 - loss: 1.0844 - val_accuracy: 0.5395 - val_loss: 1.0980
# Epoch 26/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5466 - loss: 1.0800 - val_accuracy: 0.5395 - val_loss: 1.0951
# Epoch 27/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5424 - loss: 1.0812 - val_accuracy: 0.5357 - val_loss: 1.0960
# Epoch 28/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5299 - loss: 1.0897 - val_accuracy: 0.5370 - val_loss: 1.0954
# Epoch 29/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5487 - loss: 1.0756 - val_accuracy: 0.5446 - val_loss: 1.0918
# Epoch 30/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5487 - loss: 1.0730 - val_accuracy: 0.5395 - val_loss: 1.0928
# Epoch 31/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5464 - loss: 1.0652 - val_accuracy: 0.5434 - val_loss: 1.0903
# Epoch 32/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5317 - loss: 1.0667 - val_accuracy: 0.5485 - val_loss: 1.0967
# Epoch 33/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5532 - loss: 1.0564 - val_accuracy: 0.5434 - val_loss: 1.0867
# Epoch 34/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5571 - loss: 1.0564 - val_accuracy: 0.5485 - val_loss: 1.0909
# Epoch 35/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5707 - loss: 1.0674 - val_accuracy: 0.5485 - val_loss: 1.0836
# Epoch 36/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5495 - loss: 1.0505 - val_accuracy: 0.5446 - val_loss: 1.0829
# Epoch 37/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5604 - loss: 1.0490 - val_accuracy: 0.5383 - val_loss: 1.0870
# Epoch 38/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5487 - loss: 1.0670 - val_accuracy: 0.5446 - val_loss: 1.0824
# Epoch 39/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5464 - loss: 1.0618 - val_accuracy: 0.5370 - val_loss: 1.0841
# Epoch 40/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5521 - loss: 1.0626 - val_accuracy: 0.5421 - val_loss: 1.0840
# Epoch 41/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5553 - loss: 1.0393 - val_accuracy: 0.5408 - val_loss: 1.0786
# Epoch 42/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5694 - loss: 1.0383 - val_accuracy: 0.5459 - val_loss: 1.0756
# Epoch 43/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5624 - loss: 1.0553 - val_accuracy: 0.5472 - val_loss: 1.0753
# Epoch 44/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5577 - loss: 1.0688 - val_accuracy: 0.5523 - val_loss: 1.0738
# Epoch 45/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5565 - loss: 1.0563 - val_accuracy: 0.5510 - val_loss: 1.0773
# Epoch 46/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5551 - loss: 1.0413 - val_accuracy: 0.5472 - val_loss: 1.0737
# Epoch 47/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5690 - loss: 1.0447 - val_accuracy: 0.5523 - val_loss: 1.0728
# Epoch 48/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5592 - loss: 1.0595 - val_accuracy: 0.5459 - val_loss: 1.0739
# Epoch 49/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5570 - loss: 1.0344 - val_accuracy: 0.5459 - val_loss: 1.0716
# Epoch 50/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5673 - loss: 1.0415 - val_accuracy: 0.5510 - val_loss: 1.0736
# Epoch 51/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5577 - loss: 1.0347 - val_accuracy: 0.5587 - val_loss: 1.0698
# Epoch 52/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5508 - loss: 1.0511 - val_accuracy: 0.5497 - val_loss: 1.0732
# Epoch 53/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5608 - loss: 1.0379 - val_accuracy: 0.5536 - val_loss: 1.0670
# Epoch 54/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5592 - loss: 1.0313 - val_accuracy: 0.5536 - val_loss: 1.0667
# Epoch 55/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5657 - loss: 1.0287 - val_accuracy: 0.5548 - val_loss: 1.0678
# Epoch 56/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5691 - loss: 1.0143 - val_accuracy: 0.5612 - val_loss: 1.0660
# Epoch 57/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5555 - loss: 1.0352 - val_accuracy: 0.5459 - val_loss: 1.0677
# Epoch 58/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5703 - loss: 1.0235 - val_accuracy: 0.5536 - val_loss: 1.0642
# Epoch 59/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5438 - loss: 1.0436 - val_accuracy: 0.5548 - val_loss: 1.0654
# Epoch 60/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5731 - loss: 1.0233 - val_accuracy: 0.5561 - val_loss: 1.0667
# Epoch 61/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5613 - loss: 1.0383 - val_accuracy: 0.5612 - val_loss: 1.0639
# Epoch 62/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5709 - loss: 1.0206 - val_accuracy: 0.5523 - val_loss: 1.0693
# Epoch 63/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5643 - loss: 1.0368 - val_accuracy: 0.5599 - val_loss: 1.0665
# Epoch 64/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5667 - loss: 1.0339 - val_accuracy: 0.5574 - val_loss: 1.0614
# Epoch 65/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5735 - loss: 1.0155 - val_accuracy: 0.5510 - val_loss: 1.0613
# Epoch 66/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5740 - loss: 1.0295 - val_accuracy: 0.5536 - val_loss: 1.0679
# Epoch 67/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5565 - loss: 1.0225 - val_accuracy: 0.5638 - val_loss: 1.0602
# Epoch 68/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5528 - loss: 1.0468 - val_accuracy: 0.5536 - val_loss: 1.0613
# Epoch 69/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5746 - loss: 1.0036 - val_accuracy: 0.5612 - val_loss: 1.0640
# Epoch 70/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5862 - loss: 0.9888 - val_accuracy: 0.5625 - val_loss: 1.0609
# Epoch 71/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5656 - loss: 1.0289 - val_accuracy: 0.5536 - val_loss: 1.0601
# Epoch 72/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5747 - loss: 1.0135 - val_accuracy: 0.5638 - val_loss: 1.0628
# Epoch 73/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5753 - loss: 1.0173 - val_accuracy: 0.5561 - val_loss: 1.0594
# Epoch 74/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5626 - loss: 1.0142 - val_accuracy: 0.5651 - val_loss: 1.0643
# Epoch 75/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5696 - loss: 1.0501 - val_accuracy: 0.5663 - val_loss: 1.0619
# Epoch 76/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5683 - loss: 1.0221 - val_accuracy: 0.5612 - val_loss: 1.0607
# Epoch 77/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5675 - loss: 1.0180 - val_accuracy: 0.5510 - val_loss: 1.0592
# Epoch 78/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5775 - loss: 1.0057 - val_accuracy: 0.5625 - val_loss: 1.0611
# Epoch 79/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5591 - loss: 1.0301 - val_accuracy: 0.5638 - val_loss: 1.0595
# Epoch 80/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5854 - loss: 0.9983 - val_accuracy: 0.5523 - val_loss: 1.0589
# Epoch 81/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5637 - loss: 1.0101 - val_accuracy: 0.5599 - val_loss: 1.0563
# Epoch 82/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5660 - loss: 1.0202 - val_accuracy: 0.5638 - val_loss: 1.0597
# Epoch 83/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5680 - loss: 0.9975 - val_accuracy: 0.5561 - val_loss: 1.0652
# Epoch 84/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5641 - loss: 1.0269 - val_accuracy: 0.5523 - val_loss: 1.0649
# Epoch 85/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5438 - loss: 1.0480 - val_accuracy: 0.5548 - val_loss: 1.0574
# Epoch 86/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5675 - loss: 1.0125 - val_accuracy: 0.5548 - val_loss: 1.0605
# Epoch 87/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5537 - loss: 1.0424 - val_accuracy: 0.5651 - val_loss: 1.0567
# Epoch 88/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5727 - loss: 1.0201 - val_accuracy: 0.5587 - val_loss: 1.0561
# Epoch 89/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5721 - loss: 0.9994 - val_accuracy: 0.5612 - val_loss: 1.0596
# Epoch 90/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5741 - loss: 1.0079 - val_accuracy: 0.5663 - val_loss: 1.0567
# Epoch 91/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5731 - loss: 1.0123 - val_accuracy: 0.5714 - val_loss: 1.0546
# Epoch 92/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5757 - loss: 1.0101 - val_accuracy: 0.5651 - val_loss: 1.0549
# Epoch 93/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5545 - loss: 1.0255 - val_accuracy: 0.5651 - val_loss: 1.0546
# Epoch 94/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5773 - loss: 1.0041 - val_accuracy: 0.5689 - val_loss: 1.0534
# Epoch 95/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5671 - loss: 1.0084 - val_accuracy: 0.5574 - val_loss: 1.0557
# Epoch 96/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5709 - loss: 0.9968 - val_accuracy: 0.5625 - val_loss: 1.0557
# Epoch 97/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5838 - loss: 0.9912 - val_accuracy: 0.5625 - val_loss: 1.0582
# Epoch 98/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5723 - loss: 1.0137 - val_accuracy: 0.5548 - val_loss: 1.0593
# Epoch 99/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5692 - loss: 1.0073 - val_accuracy: 0.5548 - val_loss: 1.0593
# Epoch 100/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5683 - loss: 1.0172 - val_accuracy: 0.5612 - val_loss: 1.0603
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [8]
# Predicted class: 6, Actual class: [8]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [4]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [7]
# Predicted class: 4, Actual class: [5]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [8]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [7]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [5]
# Predicted class: 6, Actual class: [8]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [7]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [4]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [7]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [7]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 4, Actual class: [4]
# Predicted class: 4, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [7]
# Predicted class: 7, Actual class: [7]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [7]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [7]
# Predicted class: 6, Actual class: [5]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [7]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [8]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [7]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [8]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [6]
# Predicted class: 7, Actual class: [7]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [8]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [5]
# Predicted class: 6, Actual class: [7]
# Predicted class: 4, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [7]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 7, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [7]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [5]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [4]
# Predicted class: 5, Actual class: [5]
# Predicted class: 7, Actual class: [7]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 4, Actual class: [4]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 7, Actual class: [7]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [6]
# Predicted class: 4, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 4, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [7]
# Predicted class: 5, Actual class: [3]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [7]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [4]
# Predicted class: 7, Actual class: [7]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [4]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [7]
# Predicted class: 5, Actual class: [6]
# Predicted class: 4, Actual class: [4]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [4]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [4]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [7]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [5]
# Predicted class: 4, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 4, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [7]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [8]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [4]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 7, Actual class: [7]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [8]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [4]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 4, Actual class: [7]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [5]
# Predicted class: 6, Actual class: [8]
# Predicted class: 6, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [8]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [4]
# Predicted class: 6, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 7, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [4]
# Predicted class: 7, Actual class: [7]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [8]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [7]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [7]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [4]
# Predicted class: 5, Actual class: [6]
# Predicted class: 4, Actual class: [4]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [3]
# Predicted class: 4, Actual class: [4]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [5]
# Predicted class: 6, Actual class: [5]
# Predicted class: 6, Actual class: [8]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Predicted class: 7, Actual class: [8]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 4, Actual class: [6]
# Predicted class: 6, Actual class: [5]
# Predicted class: 4, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [5]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [7]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [8]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [4]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [7]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [8]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [3]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [5]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [7]
# Predicted class: 6, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 4, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [8]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [3]
# Predicted class: 6, Actual class: [8]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [7]
# Predicted class: 4, Actual class: [8]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [6]
# Predicted class: 7, Actual class: [6]
# Predicted class: 7, Actual class: [7]
# Predicted class: 7, Actual class: [7]
# Predicted class: 7, Actual class: [7]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 7, Actual class: [7]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [7]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [8]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 4, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [8]
# Predicted class: 6, Actual class: [8]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [5]
# Predicted class: 6, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Predicted class: 7, Actual class: [7]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [3]
# Predicted class: 6, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [8]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [7]
# Predicted class: 4, Actual class: [5]
# Predicted class: 4, Actual class: [5]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 4, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [6]
# Predicted class: 7, Actual class: [7]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [4]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [8]
# Predicted class: 6, Actual class: [8]
# Predicted class: 6, Actual class: [5]
# Predicted class: 5, Actual class: [7]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [5]
# Predicted class: 6, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [8]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [7]
# Predicted class: 5, Actual class: [4]
# Predicted class: 5, Actual class: [5]
# Predicted class: 4, Actual class: [5]
# Predicted class: 6, Actual class: [8]
# Predicted class: 5, Actual class: [8]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 4, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 7, Actual class: [7]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [8]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [7]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [7]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 7, Actual class: [7]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [4]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [7]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [5]
# Predicted class: 4, Actual class: [7]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 7, Actual class: [7]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [5]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [5]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 4, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [8]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [4]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [6]
# Predicted class: 4, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [8]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 7, Actual class: [8]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [4]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 4, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 4, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 4, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [5]
# Predicted class: 6, Actual class: [8]
# Predicted class: 6, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [7]
# Predicted class: 7, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 4, Actual class: [4]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [5]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [8]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 7, Actual class: [7]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 7, Actual class: [7]
# Predicted class: 6, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [7]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [8]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [7]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 6, Actual class: [7]
# Predicted class: 7, Actual class: [7]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 4, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [5]
# Predicted class: 5, Actual class: [4]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 6, Actual class: [6]
# Predicted class: 5, Actual class: [5]
# Predicted class: 5, Actual class: [6]
# Accuracy:0.4980

# %%
def draw_neural_net(ax, left, right, bottom, top, layer_sizes):
    n_layers = len(layer_sizes)
    v_spacing = (top-bottom)/float(max(layer_sizes))
    h_spacing= (right - left)/float(len(layer_sizes)-1)
    #nodes
    for n, layer_size in enumerate(layer_sizes):
        layer_top=v_spacing*(layer_size-1)/2. + (top+bottom)/2
        for m in range(layer_size):
            circle = plt.Circle((n*h_spacing + left, layer_top - m*v_spacing),v_spacing/4.,
                              color='w' , ec='k' , zorder=4)
            ax.add_artist(circle)
    #Edges
    for n, (layer_size_a, layer_size_b) in enumerate(zip(layer_sizes[:-1], layer_sizes[1:])):
        layer_top_a = v_spacing*(layer_size_a - 1)/2. + (top + bottom)/2.
        layer_top_b = v_spacing*(layer_size_b - 1)/2. + (top + bottom)/2.
        for m in range(layer_size_a):
            for o in range(layer_size_b):
                line = plt.Line2D([n*h_spacing +left, (n+1)*h_spacing + left],
                                  [layer_top_a - m*v_spacing, layer_top_b - o*v_spacing], c='k')
                ax.add_artist(line)

fig = plt.figure(figsize=(12, 12))
ax = fig.gca()
ax.axis('off')
draw_neural_net(ax, .1, .9, .1, .9, [11, 64, 32,7])
